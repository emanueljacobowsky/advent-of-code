# %% [markdown]
# # Part One

# %%
def read_movement(file_name):
    with open(file_name, "r") as file:
        movement = []
        for row in file:
            movement.append(int(row.split("\n")[0]))
    return movement

# %%
file_name = 'C:\\Users\\Emanuel\\Programme\\VSC-workspace\\advent_of_code_2021\\day1\\input_example.txt'
